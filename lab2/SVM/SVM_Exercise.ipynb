# %%
#Import necessary libraries
# Write your code here

# %%
#Load Iris Dataset
# Write your code here

# %%
#Dataset partitioning: training and testing sets
# Write your code here

# %%
#Creating an SVM classifier model
# Write your code here

# %%
#Training SVM models
# Write your code here

# %%
#Evaluating the classification performance of SVM models using test sets
# Write your code here

# %%
#Output classification accuracy
#Write your code here
